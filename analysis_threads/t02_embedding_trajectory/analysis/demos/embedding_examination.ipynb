# %% [markdown]
# # Objective
#
# This notebook demonstrates how to use `scripts/utils/extract_clip_embedding.py` for extracting CLIP embeddings,
# and validates its effectiveness by examining pairwise cosine similarity heatmaps of sample words and images.
